# %% [markdown]
# # 🧠 GyaanSetu Backend (Kaggle/Colab)
# This notebook hosts **Gemma 4** via Ollama and creates a public tunnel.
#
# **Instructions:**
# 1. Ensure GPU is enabled (T4).
# 2. Run all cells.
# 3. Copy the `.ngrok-free.app` URL to your GyaanSetu frontend config.

# %%
# !curl -fsSL https://ollama.com/install.sh | sh
# !pip install pyngrok -q

# %%
import os
import subprocess
import time

os.environ["OLLAMA_HOST"] = "0.0.0.0:11434"
os.environ["OLLAMA_ORIGINS"] = "*"

print("Starting Ollama Server...")
subprocess.Popen(["ollama", "serve"], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
time.sleep(5)
print("✅ Ollama is running.")

# %%
print("⏳ Pulling Gemma 4 (e2b)... This may take 2-5 minutes.")
# !ollama pull gemma4:e2b
print("✅ Model Loaded!")

# %%
from pyngrok import ngrok

# Setting your token
NGROK_TOKEN = "3C2sDrAjQHQ0cIwcpAWBBybDO4z_3zD7c9uXBwdo48n3yfGPa"
ngrok.set_auth_token(NGROK_TOKEN)

try:
    ngrok.kill()
    tunnel = ngrok.connect(11434)
    print("\n" + "="*50)
    print("🚀 GYAANSETU BACKEND LIVE")
    print(f"🔗 URL: {tunnel.public_url}")
    print("="*50)
except Exception as e:
    print(f"Error: {e}")
