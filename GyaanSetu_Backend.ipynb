# %% [markdown]
# # 🧠 GyaanSetu Backend (Secure Version)
# **Setup:** Add your `NGROK_TOKEN` to Colab Secrets (🔑 icon) or Kaggle Secrets before running.

# %%
# !curl -fsSL https://ollama.com/install.sh | sh
# !pip install pyngrok -q

# %%
import os, subprocess, time
os.environ["OLLAMA_HOST"] = "0.0.0.0:11434"
os.environ["OLLAMA_ORIGINS"] = "*"
subprocess.Popen(["ollama", "serve"], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
time.sleep(5)
print("✅ Ollama Running")

# %%
# !ollama pull gemma4:e2b
print("✅ Model Loaded")

# %%
from pyngrok import ngrok
import getpass

try:
    # Logic to fetch token without hardcoding
    from google.colab import userdata
    NGROK_TOKEN = userdata.get('NGROK_TOKEN')
except:
    NGROK_TOKEN = getpass.getpass("Paste Ngrok Token here: ")

ngrok.set_auth_token(NGROK_TOKEN)
ngrok.kill()
tunnel = ngrok.connect(11434)
print(f"\n🚀 URL: {tunnel.public_url}")
